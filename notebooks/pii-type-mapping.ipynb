# %% [markdown]
# # PIIType Mappings
# The following focuses on the PII mappings between what is covered in this module and what is supported
# between Cloud and Third-Party modules.
#
# >> This notebook requires initial set up steps to be completed. For more information, review readme.

# %%
from pii_codex.utils import pii_mapping_util
# Confirm data frame loaded from csv mapping file
csv_file_dataframe = pii_mapping_util.open_pii_type_mapping_csv("v1")
csv_file_dataframe
# Out:
#                                      Information_Type  \
# 0                                      Place of Birth
# 1                                                Race
# 2                                              Height
# 3                                              Weight
# 4                                      Marital Status
# 5                              Country of Citizenship
# 6                                   Shopping Behavior
# 7                                             Zipcode
# 8                                  Number of Children
# 9                                           Job Title
# 10                                           Hometown
# 11                                       Income Level
# 12                                         Occupation
# 13                                             Gender
# 14                                         Birth Date
# 15                                 Online Screen Name
# 16                                           Religion
# 17                              Political Affiliation
# 18                                  Sexual Preference
# 19                                      Email Address
# 20                                        Voice Print
# 21                                         IP Address
# 22               Home Phone Number, Cell Phone Number
# 23                                            Address
# 24                                       Work Address
# 25                           Work Contact Information
# 26                                  Work Phone Number
# 27                Family/Friend’s Contact Information
# 28                             Social Network Profile
# 29                                       Picture Face
# 30                               Mother’s Maiden Name
# 31                                 Handwriting Sample
# 32                            Driver’s License Number
# 33                        Vehicle Registration Number
# 34                               License Plate Number
# 35                                 Credit Card Number
# 36                                       Credit Score
# 37  American Bankers Association Routing Number (F...
# 38  International Banking Account Number (Financia...
# 39  United States Bank Account Number (Financial A...
# 40                                  Digital Signature
# 41                                    Medical History
# 42                                        DNA Profile
# 43                                        Fingerprint
# 44                                       Home Address
# 45                             Social Security Number
# 46                                       GPS Location
# 47                              Security/Access Codes
# 48                                          Passwords
# 49                                Health Insurance ID
# 50                                    Passport Number
# 51                                                Age
# 52                                             Person
# 53                        Crypto (Financial Accounts)
# 54                                                URL
# 55                                               Date
# 56                                    Medical License
# 57   United States Individual Taxpayer Identification
# 58                             Swift Code (Financial)
#
#                                  PII_Type Cluster_Membership_Type  \
# 0                          PLACE_OF_BIRTH      Basic Demographics
# 1                                    RACE      Basic Demographics
# 2                                  HEIGHT      Basic Demographics
# 3                                  WEIGHT      Basic Demographics
# 4                          MARITAL_STATUS      Basic Demographics
# 5                  COUNTRY_OF_CITIZENSHIP      Basic Demographics
# 6                       SHOPPING_BEHAVIOR      Basic Demographics
# 7                                 ZIPCODE      Basic Demographics
# 8                      NUMBER_OF_CHILDREN      Basic Demographics
# 9                               JOB_TITLE      Basic Demographics
# 10                               HOMETOWN      Basic Demographics
# 11                           INCOME_LEVEL      Basic Demographics
# 12                             OCCUPATION      Basic Demographics
# 13                                 GENDER      Basic Demographics
# 14                                   DATE      Basic Demographics
# 15                            SCREEN_NAME    Personal Preferences
# 16                               RELIGION    Personal Preferences
# 17                  POLITICAL_AFFILIATION    Personal Preferences
# 18                      SEXUAL_PREFERENCE    Personal Preferences
# 19                          EMAIL_ADDRESS    Personal Preferences
# 20                            VOICE_PRINT     Contact Information
# 21                             IP_ADDRESS     Contact Information
# 22                           PHONE_NUMBER     Contact Information
# 23                                ADDRESS     Contact Information
# 24                           WORK_ADDRESS     Contact Information
# 25               WORK_CONTACT_INFORMATION     Contact Information
# 26                      WORK_PHONE_NUMBER     Contact Information
# 27      FAMILY_FRIEND_CONTACT_INFORMATION   Community Interaction
# 28                 SOCIAL_NETWORK_PROFILE   Community Interaction
# 29                           PICTURE_FACE   Community Interaction
# 30                    MOTHERS_MAIDEN_NAME   Financial Information
# 31                     HANDWRITING_SAMPLE   Financial Information
# 32              US_DRIVERS_LICENSE_NUMBER   Financial Information
# 33            VEHICLE_REGISTRATION_NUMBER   Financial Information
# 34                   LICENSE_PLATE_NUMBER   Financial Information
# 35                     CREDIT_CARD_NUMBER   Financial Information
# 36                           CREDIT_SCORE   Financial Information
# 37                     ABA_ROUTING_NUMBER   Financial Information
# 38   INTERNATIONAL_BANKING_ACCOUNT_NUMBER   Financial Information
# 39                 US_BANK_ACCOUNT_NUMBER   Financial Information
# 40                      DIGITAL_SIGNATURE   Financial Information
# 41                        MEDICAL_HISTORY      Secure Identifiers
# 42                            DNA_PROFILE      Secure Identifiers
# 43                            FINGERPRINT      Secure Identifiers
# 44                           HOME_ADDRESS      Secure Identifiers
# 45              US_SOCIAL_SECURITY_NUMBER      Secure Identifiers
# 46                               LOCATION      Secure Identifiers
# 47                  SECURITY_ACCESS_CODES      Secure Identifiers
# 48                               PASSWORD      Secure Identifiers
# 49                    HEALTH_INSURANCE_ID      Secure Identifiers
# 50                     US_PASSPORT_NUMBER      Secure Identifiers
# 51                                    AGE      Basic Demographics
# 52                                 PERSON   Financial Information
# 53                                 CRYPTO   Financial Information
# 54                                    URL   Community Interaction
# 55                              DATE_TIME      Basic Demographics
# 56                        MEDICAL_LICENSE      Secure Identifiers
# 57  US_INDIVIDUAL_TAXPAYER_IDENTIFICATION      Secure Identifiers
# 58                             SWIFT_CODE   Financial Information
#
#    NIST_Category     DHS_Category HIPAA_Protected_Health_Information_Category  \
# 0       Linkable    Not Mentioned                                     NON_PHI
# 1       Linkable         Linkable                                         PHI
# 2       Linkable    Not Mentioned                                         PHI
# 3       Linkable    Not Mentioned                                         PHI
# 4       Linkable    Not Mentioned                                     NON_PHI
# 5       Linkable         Linkable                                         PHI
# 6       Linkable    Not Mentioned                                     NON_PHI
# 7       Linkable    Not Mentioned                                         PHI
# 8       Linkable    Not Mentioned                                     NON_PHI
# 9       Linkable    Not Mentioned                                     NON_PHI
# 10      Linkable    Not Mentioned                                         PHI
# 11      Linkable    Not Mentioned                                     NON_PHI
# 12      Linkable    Not Mentioned                                     NON_PHI
# 13      Linkable    Not Mentioned                                         PHI
# 14      Linkable         Linkable                                         PHI
# 15  Directly PII    Not Mentioned                                     NON_PHI
# 16      Linkable    Not Mentioned                                     NON_PHI
# 17      Linkable    Not Mentioned                                     NON_PHI
# 18      Linkable         Linkable                                     NON_PHI
# 19  Directly PII  Stand Alone PII                                         PHI
# 20  Directly PII  Stand Alone PII                                         PHI
# 21  Directly PII    Not Mentioned                                         PHI
# 22  Directly PII  Stand Alone PII                                         PHI
# 23      Linkable    Not Mentioned                                     NON_PHI
# 24      Linkable    Not Mentioned                                         PHI
# 25      Linkable    Not Mentioned                                         PHI
# 26      Linkable    Not Mentioned                                         PHI
# 27      Linkable    Not Mentioned                                     NON_PHI
# 28      Linkable    Not Mentioned                                     NON_PHI
# 29  Directly PII  Stand Alone PII                                         PHI
# 30  Directly PII         Linkable                                     NON_PHI
# 31      Linkable    Not Mentioned                                     NON_PHI
# 32  Directly PII  Stand Alone PII                                         PHI
# 33  Directly PII    Not Mentioned                                         PHI
# 34  Directly PII    Not Mentioned                                         PHI
# 35  Directly PII  Stand Alone PII                                         PHI
# 36      Linkable    Not Mentioned                                     NON_PHI
# 37  Directly PII  Stand Alone PII                                         PHI
# 38  Directly PII  Stand Alone PII                                         PHI
# 39  Directly PII  Stand Alone PII                                         PHI
# 40      Linkable    Not Mentioned                                     NON_PHI
# 41      Linkable         Linkable                                         PHI
# 42      Linkable  Stand Alone PII                                         PHI
# 43  Directly PII  Stand Alone PII                                         PHI
# 44  Directly PII  Stand Alone PII                                         PHI
# 45  Directly PII  Stand Alone PII                                         PHI
# 46      Linkable    Not Mentioned                                         PHI
# 47      Linkable         Linkable                                     NON_PHI
# 48      Linkable         Linkable                                     NON_PHI
# 49  Directly PII    Not Mentioned                                         PHI
# 50  Directly PII  Stand Alone PII                                         PHI
# 51      Linkable         Linkable                                     NON_PHI
# 52  Directly PII         Linkable                                         PHI
# 53  Directly PII         Linkable                                     NON_PHI
# 54      Linkable         Linkable                                     NON_PHI
# 55      Linkable         Linkable                                         PHI
# 56  Directly PII  Stand Alone PII                                     NON_PHI
# 57  Directly PII  Stand Alone PII                                         PHI
# 58  Directly PII  Stand Alone PII                                         PHI
#
#            Risk_Level
# 0   Semi-Identifiable
# 1   Semi-Identifiable
# 2   Semi-Identifiable
# 3   Semi-Identifiable
# 4   Semi-Identifiable
# 5   Semi-Identifiable
# 6   Semi-Identifiable
# 7   Semi-Identifiable
# 8   Semi-Identifiable
# 9   Semi-Identifiable
# 10  Semi-Identifiable
# 11  Semi-Identifiable
# 12  Semi-Identifiable
# 13  Semi-Identifiable
# 14  Semi-Identifiable
# 15       Identifiable
# 16  Semi-Identifiable
# 17  Semi-Identifiable
# 18  Semi-Identifiable
# 19       Identifiable
# 20       Identifiable
# 21       Identifiable
# 22       Identifiable
# 23  Semi-Identifiable
# 24  Semi-Identifiable
# 25  Semi-Identifiable
# 26  Semi-Identifiable
# 27  Semi-Identifiable
# 28  Semi-Identifiable
# 29       Identifiable
# 30       Identifiable
# 31  Semi-Identifiable
# 32       Identifiable
# 33       Identifiable
# 34       Identifiable
# 35       Identifiable
# 36  Semi-Identifiable
# 37       Identifiable
# 38       Identifiable
# 39       Identifiable
# 40  Semi-Identifiable
# 41  Semi-Identifiable
# 42  Semi-Identifiable
# 43       Identifiable
# 44       Identifiable
# 45       Identifiable
# 46  Semi-Identifiable
# 47  Semi-Identifiable
# 48  Semi-Identifiable
# 49       Identifiable
# 50       Identifiable
# 51  Semi-Identifiable
# 52       Identifiable
# 53  Semi-Identifiable
# 54  Semi-Identifiable
# 55  Semi-Identifiable
# 56       Identifiable
# 57       Identifiable
# 58  Semi-Identifiable

# %%
# Confirm data frame loaded from json mapping file
json_file_dataframe = pii_mapping_util.open_pii_type_mapping_json("v1")
json_file_dataframe
# Out:
#                                      Information_Type  \
# 0                                      Place of Birth
# 1                                                Race
# 2                                              Height
# 3                                              Weight
# 4                                      Marital Status
# 5                              Country of Citizenship
# 6                                   Shopping Behavior
# 7                                             Zipcode
# 8                                  Number of Children
# 9                                           Job Title
# 10                                           Hometown
# 11                                       Income Level
# 12                                         Occupation
# 13                                             Gender
# 14                                         Birth Date
# 15                                 Online Screen Name
# 16                                           Religion
# 17                              Political Affiliation
# 18                                  Sexual Preference
# 19                                      Email Address
# 20                                        Voice Print
# 21                                         IP Address
# 22               Home Phone Number, Cell Phone Number
# 23                                            Address
# 24                                       Work Address
# 25                           Work Contact Information
# 26                                  Work Phone Number
# 27                Family/Friend’s Contact Information
# 28                             Social Network Profile
# 29                                       Picture Face
# 30                               Mother’s Maiden Name
# 31                                 Handwriting Sample
# 32                            Driver’s License Number
# 33                        Vehicle Registration Number
# 34                               License Plate Number
# 35                                 Credit Card Number
# 36                                       Credit Score
# 37  American Bankers Association Routing Number (F...
# 38  International Banking Account Number (Financia...
# 39  United States Bank Account Number (Financial A...
# 40                                  Digital Signature
# 41                                    Medical History
# 42                                        DNA Profile
# 43                                        Fingerprint
# 44                                       Home Address
# 45                             Social Security Number
# 46                                       GPS Location
# 47                              Security/Access Codes
# 48                                          Passwords
# 49                                Health Insurance ID
# 50                                    Passport Number
# 51                                                Age
# 52                                             Person
# 53                        Crypto (Financial Accounts)
# 54                                                URL
# 55                                               Date
# 56                                    Medical License
# 57   United States Individual Taxpayer Identification
# 58                             Swift Code (Financial)
#
#                                  PII_Type Cluster_Membership_Type  \
# 0                          PLACE_OF_BIRTH      Basic Demographics
# 1                                    RACE      Basic Demographics
# 2                                  HEIGHT      Basic Demographics
# 3                                  WEIGHT      Basic Demographics
# 4                          MARITAL_STATUS      Basic Demographics
# 5                  COUNTRY_OF_CITIZENSHIP      Basic Demographics
# 6                       SHOPPING_BEHAVIOR      Basic Demographics
# 7                                 ZIPCODE      Basic Demographics
# 8                      NUMBER_OF_CHILDREN      Basic Demographics
# 9                               JOB_TITLE      Basic Demographics
# 10                               HOMETOWN      Basic Demographics
# 11                           INCOME_LEVEL      Basic Demographics
# 12                             OCCUPATION      Basic Demographics
# 13                                 GENDER      Basic Demographics
# 14                                   DATE      Basic Demographics
# 15                            SCREEN_NAME    Personal Preferences
# 16                               RELIGION    Personal Preferences
# 17                  POLITICAL_AFFILIATION    Personal Preferences
# 18                      SEXUAL_PREFERENCE    Personal Preferences
# 19                          EMAIL_ADDRESS    Personal Preferences
# 20                            VOICE_PRINT     Contact Information
# 21                             IP_ADDRESS     Contact Information
# 22                           PHONE_NUMBER     Contact Information
# 23                                ADDRESS     Contact Information
# 24                           WORK_ADDRESS     Contact Information
# 25               WORK_CONTACT_INFORMATION     Contact Information
# 26                      WORK_PHONE_NUMBER     Contact Information
# 27      FAMILY_FRIEND_CONTACT_INFORMATION   Community Interaction
# 28                 SOCIAL_NETWORK_PROFILE   Community Interaction
# 29                           PICTURE_FACE   Community Interaction
# 30                    MOTHERS_MAIDEN_NAME   Financial Information
# 31                     HANDWRITING_SAMPLE   Financial Information
# 32              US_DRIVERS_LICENSE_NUMBER   Financial Information
# 33            VEHICLE_REGISTRATION_NUMBER   Financial Information
# 34                   LICENSE_PLATE_NUMBER   Financial Information
# 35                     CREDIT_CARD_NUMBER   Financial Information
# 36                           CREDIT_SCORE   Financial Information
# 37                     ABA_ROUTING_NUMBER   Financial Information
# 38   INTERNATIONAL_BANKING_ACCOUNT_NUMBER   Financial Information
# 39                 US_BANK_ACCOUNT_NUMBER   Financial Information
# 40                      DIGITAL_SIGNATURE   Financial Information
# 41                        MEDICAL_HISTORY      Secure Identifiers
# 42                            DNA_PROFILE      Secure Identifiers
# 43                            FINGERPRINT      Secure Identifiers
# 44                           HOME_ADDRESS      Secure Identifiers
# 45              US_SOCIAL_SECURITY_NUMBER      Secure Identifiers
# 46                               LOCATION      Secure Identifiers
# 47                  SECURITY_ACCESS_CODES      Secure Identifiers
# 48                               PASSWORD      Secure Identifiers
# 49                    HEALTH_INSURANCE_ID      Secure Identifiers
# 50                     US_PASSPORT_NUMBER      Secure Identifiers
# 51                                    AGE      Basic Demographics
# 52                                 PERSON   Financial Information
# 53                                 CRYPTO   Financial Information
# 54                                    URL   Community Interaction
# 55                              DATE_TIME      Basic Demographics
# 56                        MEDICAL_LICENSE      Secure Identifiers
# 57  US_INDIVIDUAL_TAXPAYER_IDENTIFICATION      Secure Identifiers
# 58                             SWIFT_CODE   Financial Information
#
#    NIST_Category     DHS_Category HIPAA_Protected_Health_Information_Category  \
# 0       Linkable    Not Mentioned                                     NON_PHI
# 1       Linkable         Linkable                                         PHI
# 2       Linkable    Not Mentioned                                         PHI
# 3       Linkable    Not Mentioned                                         PHI
# 4       Linkable    Not Mentioned                                     NON_PHI
# 5       Linkable         Linkable                                         PHI
# 6       Linkable    Not Mentioned                                     NON_PHI
# 7       Linkable    Not Mentioned                                         PHI
# 8       Linkable    Not Mentioned                                     NON_PHI
# 9       Linkable    Not Mentioned                                     NON_PHI
# 10      Linkable    Not Mentioned                                         PHI
# 11      Linkable    Not Mentioned                                     NON_PHI
# 12      Linkable    Not Mentioned                                     NON_PHI
# 13      Linkable    Not Mentioned                                         PHI
# 14      Linkable         Linkable                                         PHI
# 15  Directly PII    Not Mentioned                                     NON_PHI
# 16      Linkable    Not Mentioned                                     NON_PHI
# 17      Linkable    Not Mentioned                                     NON_PHI
# 18      Linkable         Linkable                                     NON_PHI
# 19  Directly PII  Stand Alone PII                                         PHI
# 20  Directly PII  Stand Alone PII                                         PHI
# 21  Directly PII    Not Mentioned                                         PHI
# 22  Directly PII  Stand Alone PII                                         PHI
# 23      Linkable    Not Mentioned                                     NON_PHI
# 24      Linkable    Not Mentioned                                         PHI
# 25      Linkable    Not Mentioned                                         PHI
# 26      Linkable    Not Mentioned                                         PHI
# 27      Linkable    Not Mentioned                                     NON_PHI
# 28      Linkable    Not Mentioned                                     NON_PHI
# 29  Directly PII  Stand Alone PII                                         PHI
# 30  Directly PII         Linkable                                     NON_PHI
# 31      Linkable    Not Mentioned                                     NON_PHI
# 32  Directly PII  Stand Alone PII                                         PHI
# 33  Directly PII    Not Mentioned                                         PHI
# 34  Directly PII    Not Mentioned                                         PHI
# 35  Directly PII  Stand Alone PII                                         PHI
# 36      Linkable    Not Mentioned                                     NON_PHI
# 37  Directly PII  Stand Alone PII                                         PHI
# 38  Directly PII  Stand Alone PII                                         PHI
# 39  Directly PII  Stand Alone PII                                         PHI
# 40      Linkable    Not Mentioned                                     NON_PHI
# 41      Linkable         Linkable                                         PHI
# 42      Linkable  Stand Alone PII                                         PHI
# 43  Directly PII  Stand Alone PII                                         PHI
# 44  Directly PII  Stand Alone PII                                         PHI
# 45  Directly PII  Stand Alone PII                                         PHI
# 46      Linkable    Not Mentioned                                         PHI
# 47      Linkable         Linkable                                     NON_PHI
# 48      Linkable         Linkable                                     NON_PHI
# 49  Directly PII    Not Mentioned                                         PHI
# 50  Directly PII  Stand Alone PII                                         PHI
# 51      Linkable         Linkable                                     NON_PHI
# 52  Directly PII         Linkable                                         PHI
# 53  Directly PII         Linkable                                     NON_PHI
# 54      Linkable         Linkable                                     NON_PHI
# 55      Linkable         Linkable                                         PHI
# 56  Directly PII  Stand Alone PII                                     NON_PHI
# 57  Directly PII  Stand Alone PII                                         PHI
# 58  Directly PII  Stand Alone PII                                         PHI
#
#            Risk_Level
# 0   Semi-Identifiable
# 1   Semi-Identifiable
# 2   Semi-Identifiable
# 3   Semi-Identifiable
# 4   Semi-Identifiable
# 5   Semi-Identifiable
# 6   Semi-Identifiable
# 7   Semi-Identifiable
# 8   Semi-Identifiable
# 9   Semi-Identifiable
# 10  Semi-Identifiable
# 11  Semi-Identifiable
# 12  Semi-Identifiable
# 13  Semi-Identifiable
# 14  Semi-Identifiable
# 15       Identifiable
# 16  Semi-Identifiable
# 17  Semi-Identifiable
# 18  Semi-Identifiable
# 19       Identifiable
# 20       Identifiable
# 21       Identifiable
# 22       Identifiable
# 23  Semi-Identifiable
# 24  Semi-Identifiable
# 25  Semi-Identifiable
# 26  Semi-Identifiable
# 27  Semi-Identifiable
# 28  Semi-Identifiable
# 29       Identifiable
# 30       Identifiable
# 31  Semi-Identifiable
# 32       Identifiable
# 33       Identifiable
# 34       Identifiable
# 35       Identifiable
# 36  Semi-Identifiable
# 37       Identifiable
# 38       Identifiable
# 39       Identifiable
# 40  Semi-Identifiable
# 41  Semi-Identifiable
# 42  Semi-Identifiable
# 43       Identifiable
# 44       Identifiable
# 45       Identifiable
# 46  Semi-Identifiable
# 47  Semi-Identifiable
# 48  Semi-Identifiable
# 49       Identifiable
# 50       Identifiable
# 51  Semi-Identifiable
# 52       Identifiable
# 53  Semi-Identifiable
# 54  Semi-Identifiable
# 55  Semi-Identifiable
# 56       Identifiable
# 57       Identifiable
# 58  Semi-Identifiable

# %%
# Retrieving the entries for "IP Address" Information Type, for example
ip_address = json_file_dataframe[json_file_dataframe.Information_Type=='IP Address']
ip_address
# Out:
#    Information_Type    PII_Type Cluster_Membership_Type NIST_Category  \
# 21       IP Address  IP_ADDRESS     Contact Information  Directly PII
#
#      DHS_Category HIPAA_Protected_Health_Information_Category    Risk_Level
# 21  Not Mentioned                                         PHI  Identifiable

# %%
# Retrieving the name for PII_Type Enum from dataframe and mapping it to common PII Type
from pii_codex.models.common import PIIType

pii_type_name = ip_address.PII_Type.item()

pii_type = PIIType[pii_type_name]
print("Enum Type Name for IP Address: ", pii_type.name)
print("Enum Type Name for IP Address: ", pii_type.value)
# Out:
# Enum Type Name for IP Address:  IP_ADDRESS
# Enum Type Name for IP Address:  IP_ADDRESS

# %%
# Mapping a common PII Type to Third-Party Type (view models folder for currently supported types)
from pii_codex.models.microsoft_presidio_pii import MSFTPresidioPIIType

presidio_pii_type = MSFTPresidioPIIType[PIIType.EMAIL_ADDRESS.name]

print("Enum Type Name for Email: ", presidio_pii_type.name)
print("Enum Type Value for Email: ", presidio_pii_type.value)
# Out:
# Enum Type Name for Email:  EMAIL_ADDRESS
# Enum Type Value for Email:  EMAIL_ADDRESS
